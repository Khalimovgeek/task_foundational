# %% [markdown]
# <a href="https://colab.research.google.com/github/Khalimovgeek/task_foundational/blob/master/save_and_load.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (6.0.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (3.16.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.12/dist-packages (from h5py) (2.0.2)

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.21.0-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (7.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.81.0)
# Requirement already satisfied: keras>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow)
#   Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.47.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.5.20)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.12.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.21.0-cp312-cp312-manylinux_2_27_x86_64.whl (572.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 MB 774.2 kB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.8 MB/s eta 0:00:00
# Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 159.0 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 93.4 MB/s eta 0:00:00
# Downloading wheel-0.47.0-py3-none-any.whl (32 kB)
# Installing collected packages: libclang, flatbuffers, wheel, h5py, google_pasta, astunparse, tensorflow
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.16.0
#     Uninstalling h5py-3.16.0:
#       Successfully uninstalled h5py-3.16.0
# Successfully installed astunparse-1.6.3 flatbuffers-25.12.19 google_pasta-0.2.0 h5py-3.14.0 libclang-18.1.1 tensorflow-2.21.0 wheel-0.47.0

# %%
import tensorflow as tf
from tensorflow import keras

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

train_labels = train_labels[:1000]
test_labels = test_labels[:1000]

train_images = train_images[:1000].reshape(-1, 28 * 28) / 255.0
test_images = test_images[:1000].reshape(-1, 28 * 28) / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
def create_model():
  model = tf.keras.Sequential([
      keras.layers.Identity(input_shape=(784,)),
      keras.layers.Dense(512, activation='relu'),
      keras.layers.Dropout(0.2),
      keras.layers.Dense(10)
  ])
  model.compile(optimizer='adam',
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

  return model

# Create a basic model instance
model = create_model()

# Display the model's architecture
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/identity.py:16: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ identity (Identity)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 407,050 (1.55 MB)
#  Trainable params: 407,050 (1.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import os

# %%
checkpoint_path = "training_1/cp.weights.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# Train the model with the new callback
model.fit(train_images,
          train_labels,
          epochs=10,
          validation_data=(test_images, test_labels),
          callbacks=[cp_callback])  # Pass callback to training

# This may generate warnings related to saving the state of the optimizer.
# These warnings (and similar warnings throughout this notebook)
# are in place to discourage outdated usage, and can be ignored.
# Out:
# Epoch 1/10
# 21/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7775 - sparse_categorical_accuracy: 0.4410
# Epoch 1: saving model to training_1/cp.weights.h5
#
# Epoch 1: finished saving model to training_1/cp.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1265 - sparse_categorical_accuracy: 0.6890 - val_loss: 0.7027 - val_sparse_categorical_accuracy: 0.7810
# Epoch 2/10
# 23/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4306 - sparse_categorical_accuracy: 0.8941
# Epoch 2: saving model to training_1/cp.weights.h5
#
# Epoch 2: finished saving model to training_1/cp.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4090 - sparse_categorical_accuracy: 0.8860 - val_loss: 0.5493 - val_sparse_categorical_accuracy: 0.8260
# Epoch 3/10
# 22/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2939 - sparse_categorical_accuracy: 0.9130
# Epoch 3: saving model to training_1/cp.weights.h5
#
# Epoch 3: finished saving model to training_1/cp.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2882 - sparse_categorical_accuracy: 0.9240 - val_loss: 0.5071 - val_sparse_categorical_accuracy: 0.8440
# Epoch 4/10
# 23/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1866 - sparse_categorical_accuracy: 0.9479
# Epoch 4: saving model to training_1/cp.weights.h5
#
# Epoch 4: finished saving model to training_1/cp.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2007 - sparse_categorical_accuracy: 0.9480 - val_loss: 0.4611 - val_sparse_categorical_accuracy: 0.8510
# Epoch 5/10
# 23/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1546 - sparse_categorical_accuracy: 0.9649
# Epoch 5: saving model to training_1/cp.weights.h5
#
# Epoch 5: finished saving model to training_1/cp.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1496 - sparse_categorical_accuracy: 0.9650 - val_loss: 0.4389 - val_sparse_categorical_accuracy: 0.8600
# Epoch 6/10
# 23/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0929 - sparse_categorical_accuracy: 0.9907
# Epoch 6: saving model to training_1/cp.weights.h5
#
# Epoch 6: finished saving model to training_1/cp.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1199 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.4143 - val_sparse_categorical_accuracy: 0.8580
# Epoch 7/10
# 23/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0791 - sparse_categorical_accuracy: 0.9887
# Epoch 7: saving model to training_1/cp.weights.h5
#
# Epoch 7: finished saving model to training_1/cp.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0838 - sparse_categorical_accuracy: 0.9860 - val_loss: 0.3971 - val_sparse_categorical_accuracy: 0.8700
# Epoch 8/10
# 23/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0594 - sparse_categorical_accuracy: 0.9965
# Epoch 8: saving model to training_1/cp.weights.h5
#
# Epoch 8: finished saving model to training_1/cp.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0617 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.4272 - val_sparse_categorical_accuracy: 0.8610
# Epoch 9/10
# 22/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0534 - sparse_categorical_accuracy: 0.9909
# Epoch 9: saving model to training_1/cp.weights.h5
#
# Epoch 9: finished saving model to training_1/cp.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0515 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.3929 - val_sparse_categorical_accuracy: 0.8740
# Epoch 10/10
# 23/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0360 - sparse_categorical_accuracy: 0.9992
# Epoch 10: saving model to training_1/cp.weights.h5
#
# Epoch 10: finished saving model to training_1/cp.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0353 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.4335 - val_sparse_categorical_accuracy: 0.8560

# %%
from re import VERBOSE
# Create a basic model instance
model = create_model()

# Evaluate the model
loss, acc = model.evaluate(test_images, test_labels, verbose=2)
print("Untrained model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 32/32 - 0s - 4ms/step - loss: 2.3196 - sparse_categorical_accuracy: 0.1490
# Untrained model, accuracy: 14.90%

# %%
# Loads the weights
model.load_weights(checkpoint_path)

# Re-evaluate the model
loss, acc = model.evaluate(test_images, test_labels, verbose=2)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 32/32 - 0s - 2ms/step - loss: 0.4335 - sparse_categorical_accuracy: 0.8560
# Restored model, accuracy: 85.60%
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# Include the epoch in the file name (uses `str.format`)
checkpoint_path = "training_2/cp-{epoch:04d}.weights.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)
os.makedirs(checkpoint_dir, exist_ok=True)
batch_size = 32

# Calculate the number of batches per epoch
import math
n_batches = len(train_images) / batch_size
n_batches = math.ceil(n_batches)    # round up the number of batches to the nearest whole integer

# Create a callback that saves the model's weights every 5 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq=5*n_batches)

# Create a new model instance
model = create_model()

# Save the weights using the `checkpoint_path` format
model.save_weights(checkpoint_path.format(epoch=0))

# Train the model with the new callback
model.fit(train_images,
          train_labels,
          epochs=50,
          batch_size=batch_size,
          callbacks=[cp_callback],
          validation_data=(test_images, test_labels),
          verbose=0)
# Out:
# Epoch 5: saving model to training_2/cp-0005.weights.h5
#
# Epoch 5: finished saving model to training_2/cp-0005.weights.h5
#
# Epoch 10: saving model to training_2/cp-0010.weights.h5
#
# Epoch 10: finished saving model to training_2/cp-0010.weights.h5
#
# Epoch 15: saving model to training_2/cp-0015.weights.h5
#
# Epoch 15: finished saving model to training_2/cp-0015.weights.h5
#
# Epoch 20: saving model to training_2/cp-0020.weights.h5
#
# Epoch 20: finished saving model to training_2/cp-0020.weights.h5
#
# Epoch 25: saving model to training_2/cp-0025.weights.h5
#
# Epoch 25: finished saving model to training_2/cp-0025.weights.h5
#
# Epoch 30: saving model to training_2/cp-0030.weights.h5
#
# Epoch 30: finished saving model to training_2/cp-0030.weights.h5
#
# Epoch 35: saving model to training_2/cp-0035.weights.h5
#
# Epoch 35: finished saving model to training_2/cp-0035.weights.h5
#
# Epoch 40: saving model to training_2/cp-0040.weights.h5
#
# Epoch 40: finished saving model to training_2/cp-0040.weights.h5
#
# Epoch 45: saving model to training_2/cp-0045.weights.h5
#
# Epoch 45: finished saving model to training_2/cp-0045.weights.h5
#
# Epoch 50: saving model to training_2/cp-0050.weights.h5
#
# Epoch 50: finished saving model to training_2/cp-0050.weights.h5

# %%
os.listdir(checkpoint_dir)
# Out:
# ['cp-0035.weights.h5',
#  'cp-0040.weights.h5',
#  'cp-0005.weights.h5',
#  'cp-0015.weights.h5',
#  'cp-0010.weights.h5',
#  'cp-0025.weights.h5',
#  'cp-0000.weights.h5',
#  'cp-0030.weights.h5',
#  'cp-0020.weights.h5',
#  'cp-0050.weights.h5',
#  'cp-0045.weights.h5']

# %%
latest = tf.train.latest_checkpoint(checkpoint_dir)
latest

# %%
import glob
import os

# Find all .weights.h5 files in the directory
checkpoint_dir = "training_2"
files = glob.glob(os.path.join(checkpoint_dir, "*.weights.h5"))

if files:
    # Get the file with the latest modification time
    latest = max(files, key=os.path.getmtime)
    print(f"Loading weights from: {latest}")
    model.load_weights(latest)
else:
    print("No checkpoints found in the directory.")
# Out:
# Loading weights from: training_2/cp-0050.weights.h5

# %%
loss, acc = model.evaluate(test_images, test_labels, verbose=2)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 32/32 - 0s - 2ms/step - loss: 0.5027 - sparse_categorical_accuracy: 0.8720
# Restored model, accuracy: 87.20%
